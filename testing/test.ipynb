# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tes

df = pd.read_csv("pharmacy_sales_dummy_1500.csv")
df.head()
# Out:
#          Date     Medicine Name    Category      Company  Batch  \
# 0  2024-10-08  Azithromycin 500  Antibiotic   Sun Pharma  B2424
# 1  2024-01-31       Telmisartan       Heart   Sun Pharma  B4257
# 2  2025-04-04       Telmisartan       Heart  Dr. Reddy's  B7924
# 3  2024-08-08        Vitamin D3     Vitamin      Mankind  B6881
# 4  2024-02-14       Zinc Tablet  Supplement      Torrent  B5803
#
#    Quantity Sold  Selling Price  Purchase Price  Stock Expiry Date  \
# 0             14         135.97          116.24    346  2026-10-16
# 1             78          60.10           49.41     13  2026-02-23
# 2              1         403.96          268.46    388  2026-03-13
# 3             12         546.75          431.09    194  2025-05-14
# 4             49         452.22          330.54     40  2026-02-28
#
#           Supplier
# 0  LifeMed Traders
# 1  LifeMed Traders
# 2       PharmaLink
# 3       PharmaLink
# 4  LifeMed Traders

# %%
df.size
# Out:
# 16500

# %%
df.shape
# Out:
# (1500, 11)

# %%
df.isnull().sum()
# Out:
# Date              0
# Medicine Name     0
# Category          0
# Company           0
# Batch             0
# Quantity Sold     0
# Selling Price     0
# Purchase Price    0
# Stock             0
# Expiry Date       0
# Supplier          0
# dtype: int64

# %%
df["Sales"] = df["Quantity Sold"] * df["Selling Price"]

# Category Sales
category = df.groupby("Category")["Sales"].sum()

plt.figure(figsize=(7,7))
plt.pie(
    category,
    labels=category.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Category Wise Sales")
plt.axis("equal")
plt.show()
